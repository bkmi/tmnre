# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from functools import partial
from copy import deepcopy
from toolz import compose, valmap, keyfilter, identity
from itertools import combinations, product
import pickle

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch

import sbi
import sbi.utils
import sbi.inference
import sbi.analysis
import sbibm

import swyft
import swyft.utils.constrainedcorner as cc

import tmnre
import tmnre.metrics
import tmnre.benchmark
import tmnre.coverage.oned
from tmnre.nn.resnet import make_resenet_tail
from tmnre.marginalize import filter_marginals_by_dim

# %%
def get_rotation_matrix(d: int) -> np.ndarray:
    # We aim to rotate x to y
    x = np.ones((d, 1))
    y = np.zeros((d, 1))
    y[-1, :] = 1.0

    # Create orthonormal basis for the planar subspace
    u = x / np.linalg.norm(x)
    v = y - np.dot(u.T, y) * u
    v /= np.linalg.norm(v)

    # Create rotation matrix within planar subspace
    cos_theta = np.dot(x.T, y).flatten() / (np.linalg.norm(x) * np.linalg.norm(y))
    sin_theta = np.sqrt(1 - cos_theta ** 2)
    R_theta = np.array([[cos_theta, -sin_theta], [sin_theta, cos_theta]]).squeeze()
    uv = np.concatenate([u, v], axis=-1)

    # Assemble total rotation (I - uu' - vv') + ([u, v] R [u, v].T) == Project onto complement + project onto rotated planar subspace
    return np.eye(d) - np.dot(u, u.T) - np.dot(v, v.T) + uv @ R_theta @ uv.T

def get_new_uniform_bounds(q, d):
    box_corners = np.asarray(list(product([0.0, 1.0], repeat=d))).T
    upper_bounds = (q @ box_corners).max(axis=1).tolist()
    lower_bounds = (q @ box_corners).min(axis=1).tolist()
    bounds = list(zip(lower_bounds, upper_bounds))
    return bounds

Q = get_rotation_matrix(10)
Qt = torch.from_numpy(Q).float()
new_bounds = get_new_uniform_bounds(Q, 10)
new_bounds
# Out:
# [(-0.9240253073352042, 0.9240253073352043),
#  (-0.9240253073352042, 0.9240253073352043),
#  (-0.9240253073352042, 0.9240253073352043),
#  (-0.9240253073352042, 0.9240253073352043),
#  (-0.9240253073352042, 0.9240253073352043),
#  (-0.9240253073352042, 0.9240253073352043),
#  (-0.9240253073352042, 0.9240253073352043),
#  (-0.9240253073352042, 0.9240253073352043),
#  (-0.9240253073352042, 0.9240253073352043),
#  (0.0, 3.1622776601683795)]

# %%
np.diff(new_bounds).prod()
# Out:
# 795.1054935299572

# %%
keepdim = 3
our_range = list(range(keepdim)) + [9]
indstokeep = list(combinations(our_range, 2)) + [(i,) for i in our_range]
keep = lambda x: x in indstokeep
indstokeep
# Out:
# [(0, 1), (0, 2), (0, 9), (1, 2), (1, 9), (2, 9), (0,), (1,), (2,), (9,)]

# %%
labels = [r"$\theta_{" + str(i) + "}$" for i in our_range]

rot_truth = Q @ (0.25 * np.ones(10))

kwargs = dict(
#     kde=True,
    kde=False,
    bins=50,
    figsize=(2.5, 2.5),
    truth=rot_truth,
    xlim=np.array(new_bounds)[our_range, :].tolist(),        # THESE ARE DIFFERENT FOR LAST DIM
    ylim_lower=np.array(new_bounds)[our_range, :].tolist(),  # THESE ARE DIFFERENT FOR LAST DIM
    labels=labels,
    ticklabels=False,
    ticklabelsize="small",
)

fittext_kwargs = dict(
    y=0.8,
    fontsize="x-large",
)

save_kwargs = dict(
    bbox_inches='tight',
    dpi=300,
    facecolor="white",
    transparent=False,
)

# %%
# double check we did the rotation correctly.
TASK_NAME = "eggbox"
NUM_OBS = 1
DIM = 10

task = sbibm.get_task(
    TASK_NAME,
    dim=DIM,
)

theta0 = task.get_true_parameters(NUM_OBS).squeeze()
sim = compose(task.g, lambda x: Qt.t() @ x)
sim(Qt @ theta0)
# Out:
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000, 0.5000,
#         0.5000])

# %% [markdown]
# ## Reference

# %%
path = f"../eggbox-{10}-ref.pickle"
with open(path, "rb") as f:
    _, ref_samples = pickle.load(f)

rot_ref_samples = np.dot(ref_samples, Q.T)
rot_ref_marginals = tmnre.marginalize.all_marginals(rot_ref_samples)

# %%
dfs = swyft.utils.get_df_dict_from_marginals(rot_ref_marginals)
dfs = keyfilter(keep, dfs)

fig, axes = cc.corner(
    dfs,
    **kwargs,
)
plt.figtext(
    s="Ground Truth",
    x=0.35,
    **fittext_kwargs,
)
# fig.savefig("figures/eggbox-ref-corner.png", **save_kwargs)
# Out:
# 6it [00:00, 46.87it/s]
# Text(0.35, 0.8, 'Ground Truth')

# %%
dfs = swyft.utils.get_df_dict_from_marginals(rot_ref_marginals)
# dfs = keyfilter(keep, dfs)

kw2 = kwargs.copy()
kw2['figsize'] = (10, 10)
kw2.pop("xlim")
kw2.pop("ylim_lower")
kw2["labels"] = [r"$\theta_{" + str(i) + "}$" for i in range(10)]

fig, axes = cc.corner(
    dfs,
#     **kwargs,
    **kw2,
)
plt.figtext(
    s="Ground Truth",
    x=0.35,
    **fittext_kwargs,
)
# fig.savefig("figures/eggbox-ref-corner.png", **save_kwargs)
# Out:
# 45it [00:01, 44.26it/s]
# Text(0.35, 0.8, 'Ground Truth')

# %% [markdown]
# # periodic ground truth

# %%
# copies
translations = np.asarray(list(product([0.0, 1.0], repeat=10)))
translations = np.concatenate([translations, -translations[1:, :]], axis=0)

# periodic
rfs = (ref_samples[None, ...] + translations[:, None, :]).reshape(-1, 10)
# rfs = ref_samples

# rotate
rfs = np.dot(rfs, Q.T)

# %%
# subsample
rng = np.random.default_rng()
rfs_sub = rng.choice(rfs, rfs.shape[0] // 10, axis=0)

# marginalize
rfm = tmnre.marginalize.all_marginals(rfs_sub)
dfs = swyft.utils.get_df_dict_from_marginals(rfm)

# plot
kw2 = kwargs.copy()
kw2['figsize'] = (10, 10)
kw2["xlim"] = new_bounds
kw2["ylim_lower"] = new_bounds
kw2["labels"] = [r"$\theta_{" + str(i) + "}$" for i in range(10)]

fig, axes = cc.corner(
    dfs,
    **kw2,
)
plt.figtext(
    s="Ground Truth",
    x=0.35,
    **fittext_kwargs,
)
# fig.savefig("figures/eggbox-ref-corner.png", **save_kwargs)
# Out:
# 45it [00:19,  2.34it/s]
# Text(0.35, 0.8, 'Ground Truth')

# %% [markdown]
# ### plot a small image

# %%
dfs = keyfilter(keep, dfs)
fig, axes = cc.corner(
    dfs,
    **kwargs,
)
plt.figtext(
    s="Ground Truth",
    x=0.35,
    **fittext_kwargs,
)
fig.savefig("figures/rot-eggbox-ref-corner.png", **save_kwargs)
# Out:
# 6it [00:02,  2.43it/s]

# %% [markdown]
# # swyft

# %%
path = f"rot-swyft-samples.pickle"
with open(path, "rb") as f:
    rot_swyft = pickle.load(f)
rot_swyft.keys()
# Out:
# dict_keys(['swyft/nsims-1000', 'swyft/nsims-10000', 'swyft/nsims-100000', 'rej-swyft/nsims-1000', 'rej-swyft/nsims-10000', 'rej-swyft/nsims-100000'])

# %%
relkeys = filter(lambda x: "rej-swyft" in x, rot_swyft.keys())
for k in relkeys:
    n = int(k.split("-")[-1])
    rot_swy_s = rot_swyft[k]
    dfs = swyft.utils.get_df_dict_from_marginals(rot_swy_s)
    dfs = keyfilter(keep, dfs)

    fig, axes = cc.corner(
        dfs,
        **kwargs,
    )
    plt.figtext(
        s=f"swyft {n}",
        x=0.35,
        **fittext_kwargs,
    )
fig.savefig("figures/rot-eggbox-swyft-corner.png", **save_kwargs)
# Out:
# 6it [00:00, 41.88it/s]
# 6it [00:00, 37.44it/s]
# 6it [00:00, 36.05it/s]

# %% [markdown]
# # nre

# %%
path = f"rot-sbi-samples.pickle"
with open(path, "rb") as f:
    rot_sbi = pickle.load(f)
rot_sbi.keys()
# Out:
# dict_keys(['sbi/nsims-1000', 'sbi/nsims-10000', 'sbi/nsims-100000'])

# %%
for k in rot_sbi.keys():
    n = int(k.split("-")[-1])
    rot_sbi_s = rot_sbi[k]
    marginals = tmnre.marginalize.all_marginals(rot_sbi_s)
    dfs = swyft.utils.get_df_dict_from_marginals(marginals)
    dfs = keyfilter(keep, dfs)

    fig, axes = cc.corner(
        dfs,
        **kwargs,
    )
    plt.figtext(
        s=f"nre {n}",
        x=0.35,
        **fittext_kwargs,
    )
fig.savefig("figures/rot-eggbox-nre-corner.png", **save_kwargs)
# Out:
# 6it [00:00, 40.68it/s]
# 6it [00:00, 43.36it/s]
# 6it [00:00, 42.48it/s]

# %% [markdown]
# # SNRE

# %%
path = f"rot-seq-samples.pickle"
with open(path, "rb") as f:
    rot_seq = pickle.load(f)
rot_seq.keys()
# Out:
# dict_keys(['seq/nsims-1000', 'seq/nsims-10000', 'seq/nsims-100000'])

# %%
for k in rot_seq.keys():
    n = int(k.split("-")[-1])
    rot_seq_s = rot_seq[k]
    marginals = tmnre.marginalize.all_marginals(rot_seq_s)
    dfs = swyft.utils.get_df_dict_from_marginals(marginals)
    dfs = keyfilter(keep, dfs)

    fig, axes = cc.corner(
        dfs,
        **kwargs,
    )
    plt.figtext(
        s=f"snre {n}",
        x=0.35,
        **fittext_kwargs,
    )
fig.savefig("figures/rot-eggbox-snre-corner.png", **save_kwargs)
# Out:
# 6it [00:00, 42.87it/s]
# 6it [00:00, 36.47it/s]
# 6it [00:00, 43.69it/s]

# %% [markdown]
# # NLE

# %%
path = f"rot-nle-samples.pickle"
with open(path, "rb") as f:
    rot_nle = pickle.load(f)
rot_nle.keys()
# Out:
# dict_keys(['nle/nsims-1000', 'nle/nsims-10000', 'nle/nsims-100000'])

# %%
for k in rot_nle.keys():
    n = int(k.split("-")[-1])
    rot_nle_s = rot_nle[k]
    marginals = tmnre.marginalize.all_marginals(rot_nle_s)
    dfs = swyft.utils.get_df_dict_from_marginals(marginals)
    dfs = keyfilter(keep, dfs)

    fig, axes = cc.corner(
        dfs,
        **kwargs,
    )
    plt.figtext(
        s=f"nle {n}",
        x=0.35,
        **fittext_kwargs,
    )
fig.savefig("figures/rot-eggbox-nle-corner.png", **save_kwargs)
# Out:
# 6it [00:00, 42.76it/s]
# 6it [00:00, 44.61it/s]
# 6it [00:00, 44.02it/s]

# %% [markdown]
# # SNLE

# %%
path = f"rot-snle-samples.pickle"
with open(path, "rb") as f:
    rot_snle = pickle.load(f)
rot_snle.keys()
# Out:
# dict_keys(['snle/nsims-1000', 'snle/nsims-10000', 'snle/nsims-100000'])

# %%
for k in rot_snle.keys():
    n = int(k.split("-")[-1])
    rot_snle_s = rot_snle[k]
    marginals = tmnre.marginalize.all_marginals(rot_snle_s)
    dfs = swyft.utils.get_df_dict_from_marginals(marginals)
    dfs = keyfilter(keep, dfs)

    fig, axes = cc.corner(
        dfs,
        **kwargs,
    )
    plt.figtext(
        s=f"snle {n}",
        x=0.35,
        **fittext_kwargs,
    )
fig.savefig("figures/rot-eggbox-snle-corner.png", **save_kwargs)
# Out:
# 6it [00:00, 42.86it/s]
# 6it [00:00, 44.89it/s]
# 6it [00:00, 45.05it/s]

# %%
for k in rot_snle.keys():
    n = int(k.split("-")[-1])
    rot_snle_s = rot_snle[k]
    marginals = tmnre.marginalize.all_marginals(rot_snle_s)
    dfs = swyft.utils.get_df_dict_from_marginals(marginals)
#     dfs = keyfilter(keep, dfs)

    fig, axes = cc.corner(
        dfs,
#         **kwargs,
        **kw2,
    )
    plt.figtext(
        s=f"snle {n}",
        x=0.35,
        **fittext_kwargs,
    )
# fig.savefig("figures/eggbox-ref-corner.png", **save_kwargs)
# Out:
# 45it [00:01, 38.80it/s]
# 45it [00:01, 40.50it/s]
# 45it [00:01, 41.81it/s]
